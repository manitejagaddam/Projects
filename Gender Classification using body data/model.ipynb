# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("gender_classification_v7.csv")

# %%
df.head()
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1    Male
# 1          1                          0  Female
# 2          1                          1    Male
# 3          1                          1    Male
# 4          0                          0  Female

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   long_hair                  5001 non-null   int64
#  1   forehead_width_cm          5001 non-null   float64
#  2   forehead_height_cm         5001 non-null   float64
#  3   nose_wide                  5001 non-null   int64
#  4   nose_long                  5001 non-null   int64
#  5   lips_thin                  5001 non-null   int64
#  6   distance_nose_to_lip_long  5001 non-null   int64
#  7   gender                     5001 non-null   object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 312.7+ KB

# %%
df.shape
# Out:
# (5001, 8)

# %%
y = df['gender']
x = df.drop("gender", axis = 1)

# %%
df.isnull().sum()
# Out:
# long_hair                    0
# forehead_width_cm            0
# forehead_height_cm           0
# nose_wide                    0
# nose_long                    0
# lips_thin                    0
# distance_nose_to_lip_long    0
# gender                       0
# dtype: int64

# %%
y = pd.get_dummies(y, drop_first=True, dtype = int)

# %%
y = y.values.ravel()

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_scaled = scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.45, random_state=44)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
lg = LogisticRegression()

# %%
lg.fit(x_scaled, y)
# Out:
# LogisticRegression()

# %%
y_pred_lg = lg.predict(x_test)

# %%
accuracy_score(y_test, y_pred_lg)
# Out:
# 0.9675699689027099

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.45, random_state=467)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(max_depth=50)

# %%
dt.fit(x, y)
# Out:
# DecisionTreeClassifier(max_depth=50)

# %%
y_pred_dt = dt.predict(x_test)

# %%
accuracy_score(y_test, y_pred_dt)
# Out:
# 0.9986672589960017

# %%
# 1	11.8	6.1	1	0	1	1

# %%
data = [1, 11.8, 6.1, 1, 0, 1, 1]

# %%
dt.predict([data])
# Out:
# c:\Users\manit\anaconda3\envs\ml\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
# 1 -> Male
# 0 -> Female

# %%
import pickle
with open("gender_classification.pkl", "wb") as file:
    pickle.dump(dt, file)

# %%
with open("gender_classification.pkl", "rb") as file:
    model = pickle.load(file)

# %%
y_pred_pickle = model.predict(x)

# %%
accuracy_score(y, y_pred_pickle)
# Out:
# 0.9984003199360127
